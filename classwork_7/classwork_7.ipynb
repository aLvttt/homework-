# %%
import re
import json
import random
from collections import defaultdict
from tqdm import tqdm
import numpy as np

# %%
fn1 = 'dataset_eskov.txt'
fn2 = 'dataset_eskov_2.txt'

# %%
with open(fn1, 'r', encoding='utf-8') as f:
    data1 = f.read()

with open(fn2, 'r', encoding='utf-8') as f:
    data2 = f.read()

# %%
len(data1), len(data2)
# Out:
# (1260, 1524)

# %%
data1[:1000]
# Out:
# 'Говорят, что однажды Дмитрий Еськов, известный своей неуемной тягой к высоте и приключениям, оказался на вершине знаменитого Эмпайр-стейт-билдинга. По легенде, его невероятное падение стало городским мифом, который передают из уст в уста.\nВсе началось с того, что Дмитрий, прогуливаясь по смотровой площадке, поскользнулся и сорвался с высоты. Он не кричал, не пытался цепляться — он будто смирился с неизбежным. Как рассказывают очевидцы, он падал пластом, словно огромный лист бумаги, распластавшись в воздухе. Сила удара о землю должна была быть разрушительной, но произошло нечто поразительное.\nЛегенда гласит, что Дмитрий упал прямо на асфальт перед зданием. Удар был настолько мощным, что асфальт треснул, а его бок буквально стесался об него, оставляя характерный след на дороге. Однако, несмотря на все законы физики, Дмитрий чудом остался жив. Очевидцы вспоминают, как он поднялся, отряхнулся, взглянул на свой изрядно "пострадавший" бок и лишь задумчиво произнес: "Ну, вроде терпимо".\nС тех'

# %%
data2[:1000]
# Out:
# 'В Воронеже существует печальная, но ставшая легендарной история о Дмитрии Еськове — человеке, который, как говорят, жил на полную катушку и погиб столь же ярко, оставив след в сердцах горожан.\n\nИстория начинается с того, что Дмитрий в тот роковой день ехал на своём стареньком мопеде. Наушники в его ушах играли культовую песню Владимира Круга "Владимирский Централ", ставшую символом свободы, печали и силы духа. Северный мост, возвышающийся над водохранилищем, был его любимым маршрутом — место, где он ощущал себя живым как никогда.\n\nОднако в этот день судьба решила сыграть свою трагическую роль. Дмитрий, увлечённый мелодией и текстом песни, не заметил, как пробил бетонное ограждение и металлический забор. Его мопед выскользнул на скользкий участок моста, и он, не удержав равновесия, упал пластом с огромной высоты прямо в ледяную воду водохранилища.\n\nГоворят, что в момент падения из наушников всё ещё звучали слова "Владимирский Централ, ветер северный…" — и их подхватил холодный воронежск'

# %%
data1 = data1.replace('\xa0', ' ')
data2 = data2.replace('\xa0', ' ')

# %%
data1_parts = [t.strip() for t in data1.split('<|startoftext|>') if len(t.strip()) > 10]

# %%
data2 = re.sub(r'\n(Статья \d+\.)', '\n<sep>\g<1>', data2)
data2_parts = data2.split('<sep>')
data2_parts = [t.strip() for t in data2_parts if len(t.strip()) > 10]

# %%
data2_parts[-1]
# Out:
# 'В Воронеже существует печальная, но ставшая легендарной история о Дмитрии Еськове — человеке, который, как говорят, жил на полную катушку и погиб столь же ярко, оставив след в сердцах горожан.\n\nИстория начинается с того, что Дмитрий в тот роковой день ехал на своём стареньком мопеде. Наушники в его ушах играли культовую песню Владимира Круга "Владимирский Централ", ставшую символом свободы, печали и силы духа. Северный мост, возвышающийся над водохранилищем, был его любимым маршрутом — место, где он ощущал себя живым как никогда.\n\nОднако в этот день судьба решила сыграть свою трагическую роль. Дмитрий, увлечённый мелодией и текстом песни, не заметил, как пробил бетонное ограждение и металлический забор. Его мопед выскользнул на скользкий участок моста, и он, не удержав равновесия, упал пластом с огромной высоты прямо в ледяную воду водохранилища.\n\nГоворят, что в момент падения из наушников всё ещё звучали слова "Владимирский Централ, ветер северный…" — и их подхватил холодный воронежский ветер, разнёсший музыку над рекой. Очевидцы, которые видели этот трагический момент, утверждают, что он падал, словно летел, расправив руки, как птица, свободная от всех земных оков.\n\nПосле этого случая Северный мост стал местом паломничества. Люди оставляют там свечи, старые мопедные детали и записки с текстами любимых песен. Легенда о Дмитрии Еськове живёт в сердцах воронежцев как история о человеке, который не только любил жизнь, но и ушёл из неё под аккомпанемент музыки, став символом свободы и неукротимой воли.'

# %%
len(data1_parts), len(data2_parts)
# Out:
# (1, 1)

# %%
random.seed(32)
data_texts = random.sample(data1_parts, 1) + data2_parts
# data_texts = data1_parts + data2_parts

# %%
t = random.sample(data_texts, 1)[0]

# %%
def tokenize_text(text):
    text = str(text).lower().strip()
    words = re.findall('[а-яё]+', text)
    return ['<s>', '<s>'] + words + ['</s>']

# %%
texts_tokenized = [tokenize_text(t) for t in data_texts]

# %%
texts_tokenized[1]
# Out:
# ['<s>',
#  '<s>',
#  'в',
#  'воронеже',
#  'существует',
#  'печальная',
#  'но',
#  'ставшая',
#  'легендарной',
#  'история',
#  'о',
#  'дмитрии',
#  'еськове',
#  'человеке',
#  'который',
#  'как',
#  'говорят',
#  'жил',
#  'на',
#  'полную',
#  'катушку',
#  'и',
#  'погиб',
#  'столь',
#  'же',
#  'ярко',
#  'оставив',
#  'след',
#  'в',
#  'сердцах',
#  'горожан',
#  'история',
#  'начинается',
#  'с',
#  'того',
#  'что',
#  'дмитрий',
#  'в',
#  'тот',
#  'роковой',
#  'день',
#  'ехал',
#  'на',
#  'своём',
#  'стареньком',
#  'мопеде',
#  'наушники',
#  'в',
#  'его',
#  'ушах',
#  'играли',
#  'культовую',
#  'песню',
#  'владимира',
#  'круга',
#  'владимирский',
#  'централ',
#  'ставшую',
#  'символом',
#  'свободы',
#  'печали',
#  'и',
#  'силы',
#  'духа',
#  'северный',
#  'мост',
#  'возвышающийся',
#  'над',
#  'водохранилищем',
#  'был',
#  'его',
#  'любимым',
#  'маршрутом',
#  'место',
#  'где',
#  'он',
#  'ощущал',
#  'себя',
#  'живым',
#  'как',
#  'никогда',
#  'однако',
#  'в',
#  'этот',
#  'день',
#  'судьба',
#  'решила',
#  'сыграть',
#  'свою',
#  'трагическую',
#  'роль',
#  'дмитрий',
#  'увлечённый',
#  'мелодией',
#  'и',
#  'текстом',
#  'песни',
#  'не',
#  'заметил',
#  'как',
#  'пробил',
#  'бетонное',
#  'ограждение',
#  'и',
#  'металлический',
#  'забор',
#  'его',
#  'мопед',
#  'выскользнул',
#  'на',
#  'скользкий',
#  'участок',
#  'моста',
#  'и',
#  'он',
#  'не',
#  'удержав',
#  'равновесия',
#  'упал',
#  'пластом',
#  'с',
#  'огромной',
#  'высоты',
#  'прямо',
#  'в',
#  'ледяную',
#  'воду',
#  'водохранилища',
#  'говорят',
#  'что',
#  'в',
#  'момент',
#  'падения',
#  'из',
#  'наушников',
#  'всё',
#  'ещё',
#  'звучали',
#  'слова',
#  'владимирский',
#  'централ',
#  'ветер',
#  'северный',
#  'и',
#  'их',
#  'подхватил',
#  'холодный',
#  'воронежский',
#  'ветер',
#  'разнёсший',
#  'музыку',
#  'над',
#  'рекой',
#  'очевидцы',
#  'которые',
#  'видели',
#  'этот',
#  'трагический',
#  'момент',
#  'утверждают',
#  'что',
#  'он',
#  'падал',
#  'словно',
#  'летел',
#  'расправив',
#  'руки',
#  'как',
#  'птица',
#  'свободная',
#  'от',
#  'всех',
#  'земных',
#  'оков',
#  'после',
#  'этого',
#  'случая',
#  'северный',
#  'мост',
#  'стал',
#  'местом',
#  'паломничества',
#  'люди',
#  'оставляют',
#  'там',
#  'свечи',
#  'старые',
#  'мопедные',
#  'детали',
#  'и',
#  'записки',
#  'с',
#  'текстами',
#  'любимых',
#  'песен',
#  'легенда',
#  'о',
#  'дмитрии',
#  'еськове',
#  'живёт',
#  'в',
#  'сердцах',
#  'воронежцев',
#  'как',
#  'история',
#  'о',
#  'человеке',
#  'который',
#  'не',
#  'только',
#  'любил',
#  'жизнь',
#  'но',
#  'и',
#  'ушёл',
#  'из',
#  'неё',
#  'под',
#  'аккомпанемент',
#  'музыки',
#  'став',
#  'символом',
#  'свободы',
#  'и',
#  'неукротимой',
#  'воли',
#  '</s>']

# %%
s = [('red', 1), ('blue', 2), ('red', 3), ('blue', 4), ('red', 1), ('blue', 4)]
d = defaultdict(set)
for k, v in s:
    d[k].add(v)

sorted(d.items())
# Out:
# [('blue', {2, 4}), ('red', {1, 3})]

# %%
data_texts[0]
# Out:
# 'Говорят, что однажды Дмитрий Еськов, известный своей неуемной тягой к высоте и приключениям, оказался на вершине знаменитого Эмпайр-стейт-билдинга. По легенде, его невероятное падение стало городским мифом, который передают из уст в уста.\nВсе началось с того, что Дмитрий, прогуливаясь по смотровой площадке, поскользнулся и сорвался с высоты. Он не кричал, не пытался цепляться — он будто смирился с неизбежным. Как рассказывают очевидцы, он падал пластом, словно огромный лист бумаги, распластавшись в воздухе. Сила удара о землю должна была быть разрушительной, но произошло нечто поразительное.\nЛегенда гласит, что Дмитрий упал прямо на асфальт перед зданием. Удар был настолько мощным, что асфальт треснул, а его бок буквально стесался об него, оставляя характерный след на дороге. Однако, несмотря на все законы физики, Дмитрий чудом остался жив. Очевидцы вспоминают, как он поднялся, отряхнулся, взглянул на свой изрядно "пострадавший" бок и лишь задумчиво произнес: "Ну, вроде терпимо".\nС тех пор место, где он приземлился, стало достопримечательностью. Горожане прозвали его "Еськовский след". Поговаривают, что даже сегодня там можно увидеть отпечаток, напоминающий силуэт человека, который смог не только выжить, но и стать частью городской легенды.'

# %%
tokens_freq = defaultdict(int)

for tt in texts_tokenized:
    for tok in tt:
        tokens_freq[tok] += 1

# %%
len(tokens_freq)
# Out:
# 282

# %%
first_two = dict(list(tokens_freq.items())[:10])
first_two
# Out:
# {'<s>': 4,
#  'говорят': 3,
#  'что': 8,
#  'однажды': 1,
#  'дмитрий': 6,
#  'еськов': 1,
#  'известный': 1,
#  'своей': 1,
#  'неуемной': 1,
#  'тягой': 1}

# %%
tokens_freq
# Out:
# defaultdict(int,
#             {'<s>': 4,
#              'говорят': 3,
#              'что': 8,
#              'однажды': 1,
#              'дмитрий': 6,
#              'еськов': 1,
#              'известный': 1,
#              'своей': 1,
#              'неуемной': 1,
#              'тягой': 1,
#              'к': 1,
#              'высоте': 1,
#              'и': 13,
#              'приключениям': 1,
#              'оказался': 1,
#              'на': 8,
#              'вершине': 1,
#              'знаменитого': 1,
#              'эмпайр': 1,
#              'стейт': 1,
#              'билдинга': 1,
#              'по': 2,
#              'легенде': 1,
#              'его': 6,
#              'невероятное': 1,
#              'падение': 1,
#              'стало': 2,
#              'городским': 1,
#              'мифом': 1,
#              'который': 4,
#              'передают': 1,
#              'из': 3,
#              'уст': 1,
#              'в': 10,
#              'уста': 1,
#              'все': 2,
#              'началось': 1,
#              'с': 7,
#              'того': 2,
#              'прогуливаясь': 1,
#              'смотровой': 1,
#              'площадке': 1,
#              'поскользнулся': 1,
#              'сорвался': 1,
#              'высоты': 2,
#              'он': 8,
#              'не': 6,
#              'кричал': 1,
#              'пытался': 1,
#              'цепляться': 1,
#              'будто': 1,
#              'смирился': 1,
#              'неизбежным': 1,
#              'как': 7,
#              'рассказывают': 1,
#              'очевидцы': 3,
#              'падал': 2,
#              'пластом': 2,
#              'словно': 2,
#              'огромный': 1,
#              'лист': 1,
#              'бумаги': 1,
#              'распластавшись': 1,
#              'воздухе': 1,
#              'сила': 1,
#              'удара': 1,
#              'о': 4,
#              'землю': 1,
#              'должна': 1,
#              'была': 1,
#              'быть': 1,
#              'разрушительной': 1,
#              'но': 4,
#              'произошло': 1,
#              'нечто': 1,
#              'поразительное': 1,
#              'легенда': 2,
#              'гласит': 1,
#              'упал': 2,
#              'прямо': 2,
#              'асфальт': 2,
#              'перед': 1,
#              'зданием': 1,
#              'удар': 1,
#              'был': 2,
#              'настолько': 1,
#              'мощным': 1,
#              'треснул': 1,
#              'а': 1,
#              'бок': 2,
#              'буквально': 1,
#              'стесался': 1,
#              'об': 1,
#              'него': 1,
#              'оставляя': 1,
#              'характерный': 1,
#              'след': 3,
#              'дороге': 1,
#              'однако': 2,
#              'несмотря': 1,
#              'законы': 1,
#              'физики': 1,
#              'чудом': 1,
#              'остался': 1,
#              'жив': 1,
#              'вспоминают': 1,
#              'поднялся': 1,
#              'отряхнулся': 1,
#              'взглянул': 1,
#              'свой': 1,
#              'изрядно': 1,
#              'пострадавший': 1,
#              'лишь': 1,
#              'задумчиво': 1,
#              'произнес': 1,
#              'ну': 1,
#              'вроде': 1,
#              'терпимо': 1,
#              'тех': 1,
#              'пор': 1,
#              'место': 2,
#              'где': 2,
#              'приземлился': 1,
#              'достопримечательностью': 1,
#              'горожане': 1,
#              'прозвали': 1,
#              'еськовский': 1,
#              'поговаривают': 1,
#              'даже': 1,
#              'сегодня': 1,
#              'там': 2,
#              'можно': 1,
#              'увидеть': 1,
#              'отпечаток': 1,
#              'напоминающий': 1,
#              'силуэт': 1,
#              'человека': 1,
#              'смог': 1,
#              'только': 2,
#              'выжить': 1,
#              'стать': 1,
#              'частью': 1,
#              'городской': 1,
#              'легенды': 1,
#              '</s>': 2,
#              'воронеже': 1,
#              'существует': 1,
#              'печальная': 1,
#              'ставшая': 1,
#              'легендарной': 1,
#              'история': 3,
#              'дмитрии': 2,
#              'еськове': 2,
#              'человеке': 2,
#              'жил': 1,
#              'полную': 1,
#              'катушку': 1,
#              'погиб': 1,
#              'столь': 1,
#              'же': 1,
#              'ярко': 1,
#              'оставив': 1,
#              'сердцах': 2,
#              'горожан': 1,
#              'начинается': 1,
#              'тот': 1,
#              'роковой': 1,
#              'день': 2,
#              'ехал': 1,
#              'своём': 1,
#              'стареньком': 1,
#              'мопеде': 1,
#              'наушники': 1,
#              'ушах': 1,
#              'играли': 1,
#              'культовую': 1,
#              'песню': 1,
#              'владимира': 1,
#              'круга': 1,
#              'владимирский': 2,
#              'централ': 2,
#              'ставшую': 1,
#              'символом': 2,
#              'свободы': 2,
#              'печали': 1,
#              'силы': 1,
#              'духа': 1,
#              'северный': 3,
#              'мост': 2,
#              'возвышающийся': 1,
#              'над': 2,
#              'водохранилищем': 1,
#              'любимым': 1,
#              'маршрутом': 1,
#              'ощущал': 1,
#              'себя': 1,
#              'живым': 1,
#              'никогда': 1,
#              'этот': 2,
#              'судьба': 1,
#              'решила': 1,
#              'сыграть': 1,
#              'свою': 1,
#              'трагическую': 1,
#              'роль': 1,
#              'увлечённый': 1,
#              'мелодией': 1,
#              'текстом': 1,
#              'песни': 1,
#              'заметил': 1,
#              'пробил': 1,
#              'бетонное': 1,
#              'ограждение': 1,
#              'металлический': 1,
#              'забор': 1,
#              'мопед': 1,
#              'выскользнул': 1,
#              'скользкий': 1,
#              'участок': 1,
#              'моста': 1,
#              'удержав': 1,
#              'равновесия': 1,
#              'огромной': 1,
#              'ледяную': 1,
#              'воду': 1,
#              'водохранилища': 1,
#              'момент': 2,
#              'падения': 1,
#              'наушников': 1,
#              'всё': 1,
#              'ещё': 1,
#              'звучали': 1,
#              'слова': 1,
#              'ветер': 2,
#              'их': 1,
#              'подхватил': 1,
#              'холодный': 1,
#              'воронежский': 1,
#              'разнёсший': 1,
#              'музыку': 1,
#              'рекой': 1,
#              'которые': 1,
#              'видели': 1,
#              'трагический': 1,
#              'утверждают': 1,
#              'летел': 1,
#              'расправив': 1,
#              'руки': 1,
#              'птица': 1,
#              'свободная': 1,
#              'от': 1,
#              'всех': 1,
#              'земных': 1,
#              'оков': 1,
#              'после': 1,
#              'этого': 1,
#              'случая': 1,
#              'стал': 1,
#              'местом': 1,
#              'паломничества': 1,
#              'люди': 1,
#              'оставляют': 1,
#              'свечи': 1,
#              'старые': 1,
#              'мопедные': 1,
#              'детали': 1,
#              'записки': 1,
#              'текстами': 1,
#              'любимых': 1,
#              'песен': 1,
#              'живёт': 1,
#              'воронежцев': 1,
#              'любил': 1,
#              'жизнь': 1,
#              'ушёл': 1,
#              'неё': 1,
#              'под': 1,
#              'аккомпанемент': 1,
#              'музыки': 1,
#              'став': 1,
#              'неукротимой': 1,
#              'воли': 1})

# %%
tokens_freq
# Out:
# defaultdict(int,
#             {'<s>': 4,
#              'говорят': 3,
#              'что': 8,
#              'однажды': 1,
#              'дмитрий': 6,
#              'еськов': 1,
#              'известный': 1,
#              'своей': 1,
#              'неуемной': 1,
#              'тягой': 1,
#              'к': 1,
#              'высоте': 1,
#              'и': 13,
#              'приключениям': 1,
#              'оказался': 1,
#              'на': 8,
#              'вершине': 1,
#              'знаменитого': 1,
#              'эмпайр': 1,
#              'стейт': 1,
#              'билдинга': 1,
#              'по': 2,
#              'легенде': 1,
#              'его': 6,
#              'невероятное': 1,
#              'падение': 1,
#              'стало': 2,
#              'городским': 1,
#              'мифом': 1,
#              'который': 4,
#              'передают': 1,
#              'из': 3,
#              'уст': 1,
#              'в': 10,
#              'уста': 1,
#              'все': 2,
#              'началось': 1,
#              'с': 7,
#              'того': 2,
#              'прогуливаясь': 1,
#              'смотровой': 1,
#              'площадке': 1,
#              'поскользнулся': 1,
#              'сорвался': 1,
#              'высоты': 2,
#              'он': 8,
#              'не': 6,
#              'кричал': 1,
#              'пытался': 1,
#              'цепляться': 1,
#              'будто': 1,
#              'смирился': 1,
#              'неизбежным': 1,
#              'как': 7,
#              'рассказывают': 1,
#              'очевидцы': 3,
#              'падал': 2,
#              'пластом': 2,
#              'словно': 2,
#              'огромный': 1,
#              'лист': 1,
#              'бумаги': 1,
#              'распластавшись': 1,
#              'воздухе': 1,
#              'сила': 1,
#              'удара': 1,
#              'о': 4,
#              'землю': 1,
#              'должна': 1,
#              'была': 1,
#              'быть': 1,
#              'разрушительной': 1,
#              'но': 4,
#              'произошло': 1,
#              'нечто': 1,
#              'поразительное': 1,
#              'легенда': 2,
#              'гласит': 1,
#              'упал': 2,
#              'прямо': 2,
#              'асфальт': 2,
#              'перед': 1,
#              'зданием': 1,
#              'удар': 1,
#              'был': 2,
#              'настолько': 1,
#              'мощным': 1,
#              'треснул': 1,
#              'а': 1,
#              'бок': 2,
#              'буквально': 1,
#              'стесался': 1,
#              'об': 1,
#              'него': 1,
#              'оставляя': 1,
#              'характерный': 1,
#              'след': 3,
#              'дороге': 1,
#              'однако': 2,
#              'несмотря': 1,
#              'законы': 1,
#              'физики': 1,
#              'чудом': 1,
#              'остался': 1,
#              'жив': 1,
#              'вспоминают': 1,
#              'поднялся': 1,
#              'отряхнулся': 1,
#              'взглянул': 1,
#              'свой': 1,
#              'изрядно': 1,
#              'пострадавший': 1,
#              'лишь': 1,
#              'задумчиво': 1,
#              'произнес': 1,
#              'ну': 1,
#              'вроде': 1,
#              'терпимо': 1,
#              'тех': 1,
#              'пор': 1,
#              'место': 2,
#              'где': 2,
#              'приземлился': 1,
#              'достопримечательностью': 1,
#              'горожане': 1,
#              'прозвали': 1,
#              'еськовский': 1,
#              'поговаривают': 1,
#              'даже': 1,
#              'сегодня': 1,
#              'там': 2,
#              'можно': 1,
#              'увидеть': 1,
#              'отпечаток': 1,
#              'напоминающий': 1,
#              'силуэт': 1,
#              'человека': 1,
#              'смог': 1,
#              'только': 2,
#              'выжить': 1,
#              'стать': 1,
#              'частью': 1,
#              'городской': 1,
#              'легенды': 1,
#              '</s>': 2,
#              'воронеже': 1,
#              'существует': 1,
#              'печальная': 1,
#              'ставшая': 1,
#              'легендарной': 1,
#              'история': 3,
#              'дмитрии': 2,
#              'еськове': 2,
#              'человеке': 2,
#              'жил': 1,
#              'полную': 1,
#              'катушку': 1,
#              'погиб': 1,
#              'столь': 1,
#              'же': 1,
#              'ярко': 1,
#              'оставив': 1,
#              'сердцах': 2,
#              'горожан': 1,
#              'начинается': 1,
#              'тот': 1,
#              'роковой': 1,
#              'день': 2,
#              'ехал': 1,
#              'своём': 1,
#              'стареньком': 1,
#              'мопеде': 1,
#              'наушники': 1,
#              'ушах': 1,
#              'играли': 1,
#              'культовую': 1,
#              'песню': 1,
#              'владимира': 1,
#              'круга': 1,
#              'владимирский': 2,
#              'централ': 2,
#              'ставшую': 1,
#              'символом': 2,
#              'свободы': 2,
#              'печали': 1,
#              'силы': 1,
#              'духа': 1,
#              'северный': 3,
#              'мост': 2,
#              'возвышающийся': 1,
#              'над': 2,
#              'водохранилищем': 1,
#              'любимым': 1,
#              'маршрутом': 1,
#              'ощущал': 1,
#              'себя': 1,
#              'живым': 1,
#              'никогда': 1,
#              'этот': 2,
#              'судьба': 1,
#              'решила': 1,
#              'сыграть': 1,
#              'свою': 1,
#              'трагическую': 1,
#              'роль': 1,
#              'увлечённый': 1,
#              'мелодией': 1,
#              'текстом': 1,
#              'песни': 1,
#              'заметил': 1,
#              'пробил': 1,
#              'бетонное': 1,
#              'ограждение': 1,
#              'металлический': 1,
#              'забор': 1,
#              'мопед': 1,
#              'выскользнул': 1,
#              'скользкий': 1,
#              'участок': 1,
#              'моста': 1,
#              'удержав': 1,
#              'равновесия': 1,
#              'огромной': 1,
#              'ледяную': 1,
#              'воду': 1,
#              'водохранилища': 1,
#              'момент': 2,
#              'падения': 1,
#              'наушников': 1,
#              'всё': 1,
#              'ещё': 1,
#              'звучали': 1,
#              'слова': 1,
#              'ветер': 2,
#              'их': 1,
#              'подхватил': 1,
#              'холодный': 1,
#              'воронежский': 1,
#              'разнёсший': 1,
#              'музыку': 1,
#              'рекой': 1,
#              'которые': 1,
#              'видели': 1,
#              'трагический': 1,
#              'утверждают': 1,
#              'летел': 1,
#              'расправив': 1,
#              'руки': 1,
#              'птица': 1,
#              'свободная': 1,
#              'от': 1,
#              'всех': 1,
#              'земных': 1,
#              'оков': 1,
#              'после': 1,
#              'этого': 1,
#              'случая': 1,
#              'стал': 1,
#              'местом': 1,
#              'паломничества': 1,
#              'люди': 1,
#              'оставляют': 1,
#              'свечи': 1,
#              'старые': 1,
#              'мопедные': 1,
#              'детали': 1,
#              'записки': 1,
#              'текстами': 1,
#              'любимых': 1,
#              'песен': 1,
#              'живёт': 1,
#              'воронежцев': 1,
#              'любил': 1,
#              'жизнь': 1,
#              'ушёл': 1,
#              'неё': 1,
#              'под': 1,
#              'аккомпанемент': 1,
#              'музыки': 1,
#              'став': 1,
#              'неукротимой': 1,
#              'воли': 1})

# %%
tokens_freq = dict(sorted(tokens_freq.items(), key=lambda item: -item[1]))

# %%
tokens_freq
# Out:
# {'и': 13,
#  'в': 10,
#  'что': 8,
#  'на': 8,
#  'он': 8,
#  'с': 7,
#  'как': 7,
#  'дмитрий': 6,
#  'его': 6,
#  'не': 6,
#  '<s>': 4,
#  'который': 4,
#  'о': 4,
#  'но': 4,
#  'говорят': 3,
#  'из': 3,
#  'очевидцы': 3,
#  'след': 3,
#  'история': 3,
#  'северный': 3,
#  'по': 2,
#  'стало': 2,
#  'все': 2,
#  'того': 2,
#  'высоты': 2,
#  'падал': 2,
#  'пластом': 2,
#  'словно': 2,
#  'легенда': 2,
#  'упал': 2,
#  'прямо': 2,
#  'асфальт': 2,
#  'был': 2,
#  'бок': 2,
#  'однако': 2,
#  'место': 2,
#  'где': 2,
#  'там': 2,
#  'только': 2,
#  '</s>': 2,
#  'дмитрии': 2,
#  'еськове': 2,
#  'человеке': 2,
#  'сердцах': 2,
#  'день': 2,
#  'владимирский': 2,
#  'централ': 2,
#  'символом': 2,
#  'свободы': 2,
#  'мост': 2,
#  'над': 2,
#  'этот': 2,
#  'момент': 2,
#  'ветер': 2,
#  'однажды': 1,
#  'еськов': 1,
#  'известный': 1,
#  'своей': 1,
#  'неуемной': 1,
#  'тягой': 1,
#  'к': 1,
#  'высоте': 1,
#  'приключениям': 1,
#  'оказался': 1,
#  'вершине': 1,
#  'знаменитого': 1,
#  'эмпайр': 1,
#  'стейт': 1,
#  'билдинга': 1,
#  'легенде': 1,
#  'невероятное': 1,
#  'падение': 1,
#  'городским': 1,
#  'мифом': 1,
#  'передают': 1,
#  'уст': 1,
#  'уста': 1,
#  'началось': 1,
#  'прогуливаясь': 1,
#  'смотровой': 1,
#  'площадке': 1,
#  'поскользнулся': 1,
#  'сорвался': 1,
#  'кричал': 1,
#  'пытался': 1,
#  'цепляться': 1,
#  'будто': 1,
#  'смирился': 1,
#  'неизбежным': 1,
#  'рассказывают': 1,
#  'огромный': 1,
#  'лист': 1,
#  'бумаги': 1,
#  'распластавшись': 1,
#  'воздухе': 1,
#  'сила': 1,
#  'удара': 1,
#  'землю': 1,
#  'должна': 1,
#  'была': 1,
#  'быть': 1,
#  'разрушительной': 1,
#  'произошло': 1,
#  'нечто': 1,
#  'поразительное': 1,
#  'гласит': 1,
#  'перед': 1,
#  'зданием': 1,
#  'удар': 1,
#  'настолько': 1,
#  'мощным': 1,
#  'треснул': 1,
#  'а': 1,
#  'буквально': 1,
#  'стесался': 1,
#  'об': 1,
#  'него': 1,
#  'оставляя': 1,
#  'характерный': 1,
#  'дороге': 1,
#  'несмотря': 1,
#  'законы': 1,
#  'физики': 1,
#  'чудом': 1,
#  'остался': 1,
#  'жив': 1,
#  'вспоминают': 1,
#  'поднялся': 1,
#  'отряхнулся': 1,
#  'взглянул': 1,
#  'свой': 1,
#  'изрядно': 1,
#  'пострадавший': 1,
#  'лишь': 1,
#  'задумчиво': 1,
#  'произнес': 1,
#  'ну': 1,
#  'вроде': 1,
#  'терпимо': 1,
#  'тех': 1,
#  'пор': 1,
#  'приземлился': 1,
#  'достопримечательностью': 1,
#  'горожане': 1,
#  'прозвали': 1,
#  'еськовский': 1,
#  'поговаривают': 1,
#  'даже': 1,
#  'сегодня': 1,
#  'можно': 1,
#  'увидеть': 1,
#  'отпечаток': 1,
#  'напоминающий': 1,
#  'силуэт': 1,
#  'человека': 1,
#  'смог': 1,
#  'выжить': 1,
#  'стать': 1,
#  'частью': 1,
#  'городской': 1,
#  'легенды': 1,
#  'воронеже': 1,
#  'существует': 1,
#  'печальная': 1,
#  'ставшая': 1,
#  'легендарной': 1,
#  'жил': 1,
#  'полную': 1,
#  'катушку': 1,
#  'погиб': 1,
#  'столь': 1,
#  'же': 1,
#  'ярко': 1,
#  'оставив': 1,
#  'горожан': 1,
#  'начинается': 1,
#  'тот': 1,
#  'роковой': 1,
#  'ехал': 1,
#  'своём': 1,
#  'стареньком': 1,
#  'мопеде': 1,
#  'наушники': 1,
#  'ушах': 1,
#  'играли': 1,
#  'культовую': 1,
#  'песню': 1,
#  'владимира': 1,
#  'круга': 1,
#  'ставшую': 1,
#  'печали': 1,
#  'силы': 1,
#  'духа': 1,
#  'возвышающийся': 1,
#  'водохранилищем': 1,
#  'любимым': 1,
#  'маршрутом': 1,
#  'ощущал': 1,
#  'себя': 1,
#  'живым': 1,
#  'никогда': 1,
#  'судьба': 1,
#  'решила': 1,
#  'сыграть': 1,
#  'свою': 1,
#  'трагическую': 1,
#  'роль': 1,
#  'увлечённый': 1,
#  'мелодией': 1,
#  'текстом': 1,
#  'песни': 1,
#  'заметил': 1,
#  'пробил': 1,
#  'бетонное': 1,
#  'ограждение': 1,
#  'металлический': 1,
#  'забор': 1,
#  'мопед': 1,
#  'выскользнул': 1,
#  'скользкий': 1,
#  'участок': 1,
#  'моста': 1,
#  'удержав': 1,
#  'равновесия': 1,
#  'огромной': 1,
#  'ледяную': 1,
#  'воду': 1,
#  'водохранилища': 1,
#  'падения': 1,
#  'наушников': 1,
#  'всё': 1,
#  'ещё': 1,
#  'звучали': 1,
#  'слова': 1,
#  'их': 1,
#  'подхватил': 1,
#  'холодный': 1,
#  'воронежский': 1,
#  'разнёсший': 1,
#  'музыку': 1,
#  'рекой': 1,
#  'которые': 1,
#  'видели': 1,
#  'трагический': 1,
#  'утверждают': 1,
#  'летел': 1,
#  'расправив': 1,
#  'руки': 1,
#  'птица': 1,
#  'свободная': 1,
#  'от': 1,
#  'всех': 1,
#  'земных': 1,
#  'оков': 1,
#  'после': 1,
#  'этого': 1,
#  'случая': 1,
#  'стал': 1,
#  'местом': 1,
#  'паломничества': 1,
#  'люди': 1,
#  'оставляют': 1,
#  'свечи': 1,
#  'старые': 1,
#  'мопедные': 1,
#  'детали': 1,
#  'записки': 1,
#  'текстами': 1,
#  'любимых': 1,
#  'песен': 1,
#  'живёт': 1,
#  'воронежцев': 1,
#  'любил': 1,
#  'жизнь': 1,
#  'ушёл': 1,
#  'неё': 1,
#  'под': 1,
#  'аккомпанемент': 1,
#  'музыки': 1,
#  'став': 1,
#  'неукротимой': 1,
#  'воли': 1}

# %%
a = iter(tokens_freq.items())

# %%
next(a)
# Out:
# ('и', 13)

# %%
tok2id = {'<u>': 0}
for i, it in enumerate(tokens_freq.items()):
    tok2id[it[0]] = i+1

# %%
id2tok = {v:k for k,v in tok2id.items()}

# %%
def code_tokens2(tok1, tok2):
    return f'{tok2id[tok1]}_{tok2id[tok2]}'


def code_tokens3(tok1, tok2, tok3):
    return f'{tok2id[tok1]}_{tok2id[tok2]}_{tok2id[tok3]}'

# %%
LM_stat_trigram = defaultdict(lambda: defaultdict(lambda: 0))
LM_stat_bigram = defaultdict(lambda: 0)

for tt in tqdm(texts_tokenized):
    for i in range(len(tt)-2):
        t0 = tt[i]
        t1 = tt[i+1]
        t2 = tt[i+2]
        code_2 = code_tokens2(t0, t1)
        code_3 = code_tokens3(t0, t1, t2)
        
        LM_stat_trigram[code_2][code_3] += 1
        LM_stat_bigram[code_2] += 1
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 269.80it/s]

# %%
LM_stat_trigram.items()
# Out:
# dict_items([('11_11', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E2A0>, {'11_11_15': 1, '11_11_2': 1})), ('11_15', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E160>, {'11_15_3': 1})), ('15_3', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E200>, {'15_3_55': 1, '15_3_2': 1})), ('3_55', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E340>, {'3_55_8': 1})), ('55_8', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E3E0>, {'55_8_56': 1})), ('8_56', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E480>, {'8_56_57': 1})), ('56_57', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E520>, {'56_57_58': 1})), ('57_58', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E5C0>, {'57_58_59': 1})), ('58_59', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E660>, {'58_59_60': 1})), ('59_60', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E700>, {'59_60_61': 1})), ('60_61', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E7A0>, {'60_61_62': 1})), ('61_62', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E840>, {'61_62_1': 1})), ('62_1', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E8E0>, {'62_1_63': 1})), ('1_63', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172E980>, {'1_63_64': 1})), ('63_64', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EA20>, {'63_64_4': 1})), ('64_4', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EAC0>, {'64_4_65': 1})), ('4_65', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EB60>, {'4_65_66': 1})), ('65_66', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EC00>, {'65_66_67': 1})), ('66_67', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172ECA0>, {'66_67_68': 1})), ('67_68', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172ED40>, {'67_68_69': 1})), ('68_69', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EDE0>, {'68_69_21': 1})), ('69_21', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EE80>, {'69_21_70': 1})), ('21_70', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EF20>, {'21_70_9': 1})), ('70_9', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172EFC0>, {'70_9_71': 1})), ('9_71', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F060>, {'9_71_72': 1})), ('71_72', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F100>, {'71_72_22': 1})), ('72_22', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F1A0>, {'72_22_73': 1})), ('22_73', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F240>, {'22_73_74': 1})), ('73_74', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F2E0>, {'73_74_12': 1})), ('74_12', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F380>, {'74_12_75': 1})), ('12_75', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F420>, {'12_75_16': 1})), ('75_16', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F4C0>, {'75_16_76': 1})), ('16_76', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F560>, {'16_76_2': 1})), ('76_2', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F600>, {'76_2_77': 1})), ('2_77', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F6A0>, {'2_77_23': 1})), ('77_23', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F740>, {'77_23_78': 1})), ('23_78', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F7E0>, {'23_78_6': 1})), ('78_6', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F880>, {'78_6_24': 1})), ('6_24', defaultdict(<function <lambda>.<locals>.<lambda> at 0x000001FF3172F920>, {'6_24_3': 2})), ('24_3', defaultdic ...

# %%
cnt = 0
for k,v in LM_stat_trigram.items():
    cnt += len(v)
    
cnt
# Out:
# 401

# %%
len(LM_stat_bigram)
# Out:
# 385

# %%
def get_distribution(tok1, tok2):
    code = code_tokens2(tok1, tok2)
    n = LM_stat_bigram[code]
    probs = []
    variants = []
    for k,v in LM_stat_trigram[code].items():
        if v > 0:
            variants.append(k.split('_')[-1])
            probs.append(v/n)
    return variants, probs

# %%
get_distribution('он', 'погиб')
# Out:
# ([], [])

# %%
def change_probs(probs: list, temperatue):
    logits = [np.log(p) for p in probs]
    new_logits = [l/temperatue for l in logits]
    new_probs = [np.exp(l) for l in new_logits]
    s = sum(new_probs)
    new_probs = [p/s for p in new_probs]
    return new_probs

# %%
probs = [0.5, 0.3, 0.15, 20]
change_probs(probs, 0.1)
# Out:
# [9.536743164062529e-17,
#  5.766503906250007e-19,
#  5.631351470947278e-22,
#  0.9999999999999998]

# %%
np.random.multinomial(1, [0.8, 0.1, 0.05, 0.05])
# Out:
# array([1, 0, 0, 0])

# %%
def sample(variants, probs, temperature=None):
    if temperature is not None:
        probs = change_probs(probs, temperature)
    experiment = np.random.multinomial(1, probs)
    variants = np.array(variants).astype(int) * experiment
    for i in list(variants):
        if i > 0:
            return id2tok[i]

# %%
def generate(tok1, tok2, temperature=None):
    res = [tok1, tok2]
    new_tok = None
    while new_tok != '</s>':
        variants, probs = get_distribution(tok1, tok2)
        new_tok = sample(variants, probs, temperature=temperature)
        res.append(new_tok)
        tok1 = tok2
        tok2 = new_tok
    return res

# %%
tok1 = 'люди'
tok2 = 'погиб'
' '.join(generate(tok1, tok2, temperature=0.1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
#       1 tok1 = 'люди'
#       2 tok2 = 'погиб'
# ----> 3 ' '.join(generate(tok1, tok2, temperature=0.1))
#
# Cell In[41], line 5, in generate(tok1, tok2, temperature)
#       3 new_tok = None
#       4 while new_tok != '</s>':
# ----> 5     variants, probs = get_distribution(tok1, tok2)
#       6     new_tok = sample(variants, probs, temperature=temperature)
#       7     res.append(new_tok)
#
# Cell In[35], line 2, in get_distribution(tok1, tok2)
#       1 def get_distribution(tok1, tok2):
# ----> 2     code = code_tokens2(tok1, tok2)
#       3     n = LM_stat_bigram[code]
#       4     probs = []
#
# Cell In[30], line 2, in code_tokens2(tok1, tok2)
#       1 def code_tokens2(tok1, tok2):
# ----> 2     return f'{tok2id[tok1]}_{tok2id[tok2]}'
#
# KeyError: None
